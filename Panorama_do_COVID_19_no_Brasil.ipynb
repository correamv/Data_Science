# %% [markdown]
# <a href="https://colab.research.google.com/github/correamv/Data_Science/blob/main/Panorama_do_COVID_19_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Panorama do COVID-19 no Brasil
#
# Declarada oficialmente em Março de 2020 pela OMS, a pandemia do COVID-19 afetou a população e economia globais de forma sem precedentes no mundo moderno.
#
# A COVID-19 é uma doença altamente infecciosa transmitida pelo ar, principalmente por gotículas de saliva emitidas por indivíduos contaminados durante a fala, tosses ou espirros. Além disso a transmissão pode ser feita pelo contato com superfícies contaminadas.
#
#
# Os sintomas podem variar de pessoa para pessoa, carga viral, fatores de risco como obesidade, hipertensão e etc (uma lista completa pode ser encontrada [aqui](https://www.gov.br/saude/pt-br/coronavirus/atendimento-tratamento-e-fatores-de-risco)).
#
# Observou-se que cerca de 80% dos casos são assintomáticos ou leves, não necessitando de tratamento hospitalar, sendo tratamentos paliativos suficientes.
#
# No entanto, 15% das pessoas terão infecções graves e precisarão de oxigênio. O restante das pessoas, que representam 5%, serão classificadas como infecções muito graves e precisarão de ventilação assistida, por meio de respiradores mecânicos em ambiente hospitalar.
#
#
# <center><img alt="Colaboratory logo" width="80%" src="https://images.unsplash.com/photo-1583423230902-b653abc541eb?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1332&q=80"></center>
#
# Além disso, descobriu-se que principalmente em pacientes em que a doença se manifestou de forma moderada a grave, a COVID-19 pode deixar sequelas por tempo indefinido, como falta de ar, dificuldade na cognição e/ou memória, perda de paladar e olfato, fibrose nos pulmões e rins, entre outros.
#
# Além do gravíssimo impacto humano, o mundo sofre com os impactos econômicos causados pela pandemia. Para conter a disseminação da doença, medidas protetivas como lockdowns, precisaram ser feitas. Com isso, diversas indústrias tiveram que pausar suas atividades, causando um impacto na cadeia de suprimentos global, que persiste até os dias de hoje.
#
# Com o objetivo de mensurar a disseminação do covid-19 no Brasil, irei realizar uma análise com base nos dados públicos da doença.

# %% [markdown]
# ## Obtenção dos Dados
#
#
# Como fonte dos dados irei utilizar o dataset disponibilizado pela ***Our World in Data***, um projeto da Global Change Data Lab, uma organização sem fins lucrativos nativa da Inglaterra. Especialmente ao longo da pandemia, este time foi responsável por consolidar diversos dados ao redor do mundo, sendo crucial para diversos times de pesquisadores ao redor do globo.
#
# Para o caso específico do Brasil, os dados crus, foram coletados através do ministério da saúde e da Universidade Federal de Viçosa.
#
# Apesar do grande esforço para se adquirir dados de qualidade, a falta de testes no Brasil no início da pandemia, e a subnotificação de casos devido as diversas particularidades de cada região do país, tornam difíceis a consolidação das informações. Mas ainda assim, conseguiremos ter uma visão apurada de como a pandemia se manisfestou no país.

# %% [markdown]
# ### Dicionário de Variáveis
#
# * `iso_code` - 	ISO 3166-1 alpha-3 – códigos de país de três letras. Observe que regiões definidas pela OWID (por exemplo, continentes como ' Europa ') contêm prefixo 'OWID_'.
# * `continent` - 	Continente referente a localização geográfica
# * `location` - 	Localização Geográfica.
# * `date` - 	Data de observação
# * `total_cases` - 	Total de casos confirmados de COVID-19. Contagens pode incluir casos prováveis, quando relatado.
# * `new_cases` - 	Novos casos confirmados de COVID-19. Contagens podem incluir casos prováveis, quando relatado. Em raros casos em que nossa fonte relata uma mudança diária negativa para uma correção de dados, definimos isso métrica para NA.
# * `new_cases_smoothed` - 	Novos casos confirmados de COVID-19 (suavizado de 7 dias). Contagens pode incluir casos prováveis, quando relatado.
# * `total_deaths` - 	Total de mortes atribuídas ao COVID-19. Contagens pode incluir mortes prováveis, onde relatado.
# * `new_deaths` - 	Novas mortes atribuídas ao COVID-19. Contagens podem incluir mortes prováveis, onde relatado. Em raros casos em que nossa fonte relata uma mudança diária negativa para uma correção de dados, definimos isso métrica para NA.
# * `new_deaths_smoothed` - 	Novas mortes atribuídas ao COVID-19 (suavizado de 7 dias). Contagens pode incluir mortes prováveis, onde relatado.
# * `total_cases_per_million` - 	Total de casos confirmados de COVID-19 por 1.000.000 de pessoas. Contagens pode incluir casos prováveis, onde relatado.
# * `new_cases_per_million` - 	Novos casos confirmados de COVID-19 por 1.000.000 de pessoas. Contagens pode incluir casos prováveis, onde relatado.
# * `new_cases_smoothed_per_million` - 	Novos casos confirmados de COVID-19 (suavizado em 7 dias) por 1.000.000 de pessoas. Contagens pode incluir casos prováveis, onde relatado.
# * `total_deaths_per_million` - 	Total de mortes atribuídas ao COVID-19 por 1.000.000 de pessoas. Contagens pode incluir mortes prováveis, onde relatado.
# * `new_deaths_per_million` - 	Novas mortes atribuídas ao COVID-19 por 1.000.000 de pessoas. Contagens pode incluir mortes prováveis, onde relatado.
# * `new_deaths_smoothed_per_million` - 	Novas mortes atribuídas ao COVID-19 (suavizado de 7 dias) por 1.000.000 de pessoas. Contagens pode incluir mortes prováveis, onde relatado.
# * `reproduction_rate` - 	Estimativa em tempo real do a eficaz taxa de reprodução (R) do COVID-19. Veja https://github.com/crondonm/TrackingR/tree/main/Estimates-Database
# * `icu_patients` - 	Número de pacientes com COVID-19 em Unidades de terapia intensiva (UTIs) em um determinado dia.
# * `icu_patients_per_million` - 	Número de pacientes com COVID-19 em Unidades de terapia intensiva (UTIs) em um determinado dia por 1.000.000 pessoas.
# * `hosp_patients` - 	Número de pacientes com COVID-19 no hospital em um determinado dia.
# * `hosp_patients_per_million` - 	Número de pacientes com COVID-19 no hospital em um determinado dia por 1.000.000 pessoas.
# * `weekly_icu_admissions` - 	Número de pacientes com COVID-19 recentemente admitido para unidades de tratamento intensivo (UTIs) em uma determinada semana (data do relatório e a anterior a 6 dias).
# * `weekly_icu_admissions_per_million` - 	Número de pacientes com COVID-19 recentemente admitido para unidades de tratamento intensivo (UTIs) em uma determinada semana por 1.000.000 de pessoas (data do relatório e a anterior a 6 dias)
# * `weekly_hosp_admissions` - 	Número de pacientes com COVID-19 recentemente admitido para hospitais em uma determinada semana (data do relatório e a anterior a 6 dias)
# * `weekly_hosp_admissions_per_million` - 	Número de pacientes com COVID-19 recentemente admitido para hospitais em uma determinada semana por 1.000.000 de pessoas (data do relatório e a anterior a 6 dias)
# * `total_tests` - 	Total de testes para COVID-19
# * `new_tests` - 	Novos testes para COVID-19 (somente calculado para consecutivos dias)
# * `total_tests_per_thousand` - 	Total de testes para COVID-19 por 1.000 pessoas
# * `new_tests_per_thousand` - 	Novos testes para COVID-19 por 1.000 pessoas
# * `new_tests_smoothed` - 	Novos testes para COVID-19 (suavizado de 7 dias). Para países que não reportam dados de testes diariamente, assumimos que os testes tenham mudado igualmente diariamente sobre quaisquer períodos em que nenhum dado foi relatado. Isso produz uma série completa de números diários, que é então média ao longo de uma janela contínua de 7 dias
# * `new_tests_smoothed_per_thousand` - 	Novos testes para COVID-19 (suavizado de 7 dias) por 1.000 pessoas
# * `positive_rate` - 	A partilha de testes COVID-19 que são positivos, dados como uma média móvel de 7 dias (este é a inverso dos testes_per_case)
# * `tests_per_case` - 	Testes conduzido por novo caso confirmado de COVID-19, dado como uma média móvel de 7 dias (este é a inverso do positive_rate)
# * `tests_units` - 	Unidades usadas por a localização para relatar seus dados de teste. Um arquivo de país não pode conter unidades misturadas. Todas as métricas relativas aos dados de teste usam as unidades especificadas. Unidades válidas são ' pessoas testadas ' (número de pessoas testadas), ' testes realizados ' (número de testes realizados. Uma única pessoa pode ser testada mais de uma vez em determinado dia) e 'amostras testadas ' (número de amostras testadas. Em alguns casos, mais de uma amostra pode ser requerido para realizar um determinado teste.)
# * `total_vaccinations` - 	Número total das doses de vacinação COVID-19 administradas
# * `people_vaccinated` - 	Número total de pessoas que tenham recebido ao menos 1 dose de vacina
# * `people_fully_vaccinated` - 	Número total de pessoas que tenham recebido todas as doses prescritas pôr a inicial vacinação protocolo
# * `total_boosters` - 	Número total de doses de reforço administradas (doses administradas além do número prescrito pelo protocolo de vacinação)
# * `new_vaccinations` - 	Doses de vacinação de COVID-19 administradas (somente calculado para consecutivos dias)
# * `new_vaccinations_smoothed` - 	Doses de vacinação COVID-19 administradas (suavizado de 7 dias). Para países que não relatório dados de vacinação por dia base, assumimos que _ vacinação mudado igualmente diariamente _ _ base sobre quaisquer períodos em que nenhum dado foi relatado. este produz uma série completa de números diários, que é então média ao longo de uma janela contínua de 7 dias
# * `total_vaccinations_per_hundred` - 	Número total de doses de vacinação COVID-19 administradas por 100 pessoas na população total
# * `people_vaccinated_per_hundred` - 	Número total de pessoas que tenham recebido ao menos 1 dose da vacina por 100 pessoas na população total
# * `people_fully_vaccinated_per_hundred` - 	Número total de pessoas que tenham recebido todas as doses prescritas pôr a inicial vacinação protocolo por 100 pessoas na população total
# * `total_boosters_per_hundred` - 	Número total de vacinação COVID-19 doses de reforço administradas por 100 pessoas na população total
# * `new_vaccinations_smoothed_per_million` - 	Doses de vacinação COVID-19 administradas (suavizado em 7 dias) por 1.000.000 de pessoas na população total
# * `new_people_vaccinated_smoothed` - 	Número diário de pessoas recebendo seus primeira dose da vacina (suavizado de 7 dias)
# * `new_people_vaccinated_smoothed_per_hundred` - 	Número diário de pessoas recebendo seus primeira dose da vacina (suavizado de 7 dias) por 100 pessoas na população total
# * `stringency_index` - 	Índice de Rigidez da Resposta do Governo: composto a medida Sediada em 9 indicadores de resposta incluindo fechamento de escolas, locais de trabalho e proibições de viagens, redimensionadas para um valor de 0 a 100 (100 = resposta mais rigorosa)
# * `population` - 	População (últimos valores acessíveis). Consulte https://github.com/owid/covid-19-data/blob/master/scripts/input/un/population_latest.csv para obter a lista completa do fontes
# * `population_density` - 	Número de pessoas dividido por area, medida em quilômetros quadrados, ano mais recente disponível
# * `median_age` - 	Idade média da população, projeção da ONU para 2020
# * `aged_65_older` - 	Parte da população que é 65 anos ou mais velha, ano mais recente disponível
# * `aged_70_older` - 	Parte da população que é 70 anos ou mais velha, em 2015
# * `gdp_per_capita` - 	Produto interno bruno na paridade de poder de compra (constante 2011 internacional dólares), ano mais recente disponível.
# * `extreme_poverty` - 	Parte da população que vive em extrema pobreza, ano mais recente disponível, desde 2010
# * `cardiovasc_death_rate` - 	Taxa de mortalidade por doença cardiovascular em 2017 (anual número de mortes por 100.000 pessoas)
# * `diabetes_prevalence` - 	Prevalência de diabetes (% de população de 20 a 79 anos) em 2017
# * `female_smokers` - 	Parte das mulheres que fumam, ano mais recente disponível
# * `male_smokers` - 	Parte dos homens quem fumam, ano mais recente disponível
# * `handwashing_facilities` - 	Parte da população saneamento básico para lavar as mãos, ano mais recente disponível
# * `hospital_beds_per_thousand` - 	Leitos hospitalares por 1.000 pessoas, ano mais recente disponível desde 2010
# * `life_expectancy` - 	Expectativa de vida no nascimento em 2019
# * `human_development_index` - 	Um índice composto que mede a média da conquista em três básicas dimensões do desenvolvimento humano — um longo e saudável vida, conhecimento e um padrão de vida decente. Valores para 2019, importados de http://hdr.undp.org/en/indicators/137506
# * `excess_mortality` - 	Diferença percentual entre o número relatado semanal ou mensal, de mortes em 2020-2021 e o número projetado de mortes para o mesmo período baseado em anos anteriores. Para mais informação acesse: https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality
# * `excess_mortality_cumulative` - 	Diferença percentual entre o número relatado semanal ou mensal, de mortes desde 1 de janeiro de 2020 e o número cumulativo projetado de mortes para o mesmo período baseado em anos anteriores. Para mais informação acesse: https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality
# * `excess_mortality_cumulative_absolute` - 	Diferença percentual cumulativa entre o número reportado de mortes desde 1 de janeiro de 2020 e o número projetado de mortes para o mesmo período baseado em anos anteriores. Para mais informação acesse: https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality
# * `excess_mortality_cumulative_per_million` - 	Diferença cumulativa entre o número reportado de mortes desde o dia 1 de janeiro de 2020 e o número projetado de mortes para o mesmo período baseado em anos anteriores, por milhão de pessoas.Para mais informação acesse: https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality

# %% [markdown]
# ### Importando os dados do COVID-19
#
# * Usaremos este [link](https://github.com/owid/covid-19-data/tree/master/public/data) para importar a base de dados mais atualizada. Usaremos o formato `csv` neste projeto.
#
#
# A data em que a base de dados foi extraída é de: **01/02/2023**.
#
# <center><img alt="Colaboratory logo" width="100%" src="https://img.freepik.com/free-photo/digital-world-map-hologram-blue-background_1379-900.jpg?w=1380&t=st=1675362611~exp=1675363211~hmac=857152f2b5969d79280fff235448b1649ebafd172e2d68b3f36449a4829fa591"></center>

# %%
# importar as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import seaborn as sns

# importar o dataset COVID-19 para um DataFrame
DATA_PATH = "https://covid.ourworldindata.org/data/owid-covid-data.csv"
#"https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# Nesta etapa, irei extrair algumas informações iniciais do dataset, incluindo as variáveis disponíveis, e o percentual de valores ausentes em cada uma.
#
# Além disso, como neste momento estamos lidando com o dataset inteiro, podemos extrair algumas informações importantes a nível mundial, como por exemplo, quais foram os países com mais casos de COVID-19 e mortes até o momento atual.

# %% [markdown]
# ### Conhecendo o Dataset
# Neste primeiro momento é importante conhecermos o dataset que estamos trabalhando. Por isso iremos extrair algumas informações como:
#
# * As primeiras linhas
# * Tamanho do dataset
# * Nome das colunas
# * Quais os tipos de variáveis

# %%
#Visualizar as cinco primeiras entradas
df.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
#verificando o tamanho do dataset

print("O dataset consiste de", df.shape[0], "linhas e", df.shape[1], "colunas.")
# Out:
# O dataset consiste de 254423 linhas e 67 colunas.

# %%
#Nome das colunas
columns  = df.columns
for name in columns:
   print(name)
# Out:
# iso_code
# continent
# location
# date
# total_cases
# new_cases
# new_cases_smoothed
# total_deaths
# new_deaths
# new_deaths_smoothed
# total_cases_per_million
# new_cases_per_million
# new_cases_smoothed_per_million
# total_deaths_per_million
# new_deaths_per_million
# new_deaths_smoothed_per_million
# reproduction_rate
# icu_patients
# icu_patients_per_million
# hosp_patients
# hosp_patients_per_million
# weekly_icu_admissions
# weekly_icu_admissions_per_million
# weekly_hosp_admissions
# weekly_hosp_admissions_per_million
# total_tests
# new_tests
# total_tests_per_thousand
# new_tests_per_thousand
# new_tests_smoothed
# new_tests_smoothed_per_thousand
# positive_rate
# tests_per_case
# tests_units
# total_vaccinations
# people_vaccinated
# people_fully_vaccinated
# total_boosters
# new_vaccinations
# new_vaccinations_smoothed
# total_vaccinations_per_hundred
# people_vaccinated_per_hundred
# people_fully_vaccinated_per_hundred
# total_boosters_per_hundred
# ...

# %%
#parâmetro para definir número máximo de linhas a serem exibidas de uma vez
pd.set_option('max_rows', 99)

#tipos de variáveis
df.dtypes
# Out:
# iso_code                                       object
# continent                                      object
# location                                       object
# date                                           object
# total_cases                                   float64
# new_cases                                     float64
# new_cases_smoothed                            float64
# total_deaths                                  float64
# new_deaths                                    float64
# new_deaths_smoothed                           float64
# total_cases_per_million                       float64
# new_cases_per_million                         float64
# new_cases_smoothed_per_million                float64
# total_deaths_per_million                      float64
# new_deaths_per_million                        float64
# new_deaths_smoothed_per_million               float64
# reproduction_rate                             float64
# ...

# %% [markdown]
# É possivel verificar que ao examinarmos o tipo das variáveis no dataset, os valores das datas estão no formato `object`. Logo, iremos converter para o formato `datetime`, assim conseguimos trabalhar melhor os dados.

# %%
df.date = pd.to_datetime(df.date)

# %% [markdown]
# ### Lidando com Valores Ausentes
#
# Lidar com dados ou valores ausentes é uma etapa fundamental para qualquer análise de dados no mundo real. Estes podem ser valores que simplesmente não foram inseridos, valores que realmente podem ter o valor nulo ou valores inseridos de forma errada.
#
#
# <center><img alt="Colaboratory logo" width="80%" src="https://img.freepik.com/free-photo/white-puzzle-pieces-blue-background_641386-655.jpg?w=1380&t=st=1675362735~exp=1675363335~hmac=a416362a861a1f009fd72671a40ab31d3b67313790c2984246c1f645e7c144da"></center>
#
#
#
# Observa-se abaixo que temos dados ausentes na maioria das variáveis.Porém para a análise deste artigo, estaremos focados nas variáveis que nos mostram os números de casos mundialmente e por pais, e também no número de mortes.
#
# Veja que nas primeiras entradas temos linhas referentes ao afeganistão e que a contagem começou no dia 24 de ferereiro de 2020. Porém notamos que a variável `total_deaths` possui valores nulos para as primeiras linhas. Isso faz sentido, pois é razoável pensarmos que as primeiras mortes aconteceram alguns dias após o registo do primeiro caso.
#
# Logo, para a variável `total_deaths`" iremos tratar os valores ausentes, substituindo-os por zeros, a fim ser possível trabalharmos os dados corretamente e graficamente.
#
# Para as variáveis relacionadas a vacinação,  podemos seguir uma lógica semelhante, tendo em vista que a vacinação começou muitos meses após o início da pandemia. Apesar de as vacinas terem sido desenvolvidas em tempo recorde, ainda foram necessários alguns meses para todo o fluxo de desenvolvimento, teste, produção e distribuição. Isso explica a alta frequência de valores ausentes nesta variável (72%).

# %%
# Qual a porcentagem de valores ausentes em cada coluna?
round((df.isnull().sum() / df.shape[0]).sort_values(ascending=False),2)
# Out:
# excess_mortality_cumulative_per_million       0.97
# excess_mortality_cumulative                   0.97
# excess_mortality_cumulative_absolute          0.97
# excess_mortality                              0.97
# weekly_icu_admissions                         0.97
# weekly_icu_admissions_per_million             0.97
# weekly_hosp_admissions                        0.92
# weekly_hosp_admissions_per_million            0.92
# icu_patients                                  0.87
# icu_patients_per_million                      0.87
# hosp_patients_per_million                     0.85
# hosp_patients                                 0.85
# total_boosters                                0.84
# total_boosters_per_hundred                    0.84
# new_vaccinations                              0.77
# people_fully_vaccinated                       0.74
# people_fully_vaccinated_per_hundred           0.74
# people_vaccinated_per_hundred                 0.73
# ...

# %%
#substituindo valores ausentes

df_clean = df.copy()
sub_dict = {"total_vaccinations" : 0, 'people_vaccinated' : 0, 'new_deaths' : 0, 'new_deaths_smoothed_per_million': 0}
df_clean.fillna(sub_dict, inplace = True)

round((df_clean.isnull().sum() / df_clean.shape[0]).sort_values(ascending=False),2)

df = df_clean

# Verificando o número de valores ausentes atualizado
round((df.isnull().sum() / df.shape[0]).sort_values(ascending=False),2)
# Out:
# excess_mortality_cumulative_per_million       0.97
# excess_mortality_cumulative                   0.97
# excess_mortality_cumulative_absolute          0.97
# excess_mortality                              0.97
# weekly_icu_admissions_per_million             0.97
# weekly_icu_admissions                         0.97
# weekly_hosp_admissions_per_million            0.92
# weekly_hosp_admissions                        0.92
# icu_patients                                  0.87
# icu_patients_per_million                      0.87
# hosp_patients                                 0.85
# hosp_patients_per_million                     0.85
# total_boosters_per_hundred                    0.84
# total_boosters                                0.84
# new_vaccinations                              0.77
# people_fully_vaccinated_per_hundred           0.74
# people_fully_vaccinated                       0.74
# people_vaccinated_per_hundred                 0.73
# ...

# %% [markdown]
# ### A Covid no Mundo
#
# <center><img alt="Colaboratory logo" width="75%" src="https://images.unsplash.com/photo-1584931423298-c576fda54bd2?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=2670&q=80"></center>
#
# Agora, vejamos para a data em que este projeto está sendo escrito (01/02/23), quais são os países com mais casos e com mais mortes devido a pandemia.

# %%
#10 países com mais casos de COVID-19 no mundo:

df.loc[df.date == "2023-02-01"].sort_values(by="total_cases", ascending= False)[0:10]
# Out:
#         iso_code      continent             location       date  total_cases  \
# 251294  OWID_WRL            NaN                World 2023-02-01  670901844.0
# 99175   OWID_HIC            NaN          High income 2023-02-01  427348162.0
# 74119   OWID_EUR            NaN               Europe 2023-02-01  246589034.0
# 12903   OWID_ASI            NaN                 Asia 2023-02-01  209136044.0
# 75225   OWID_EUN            NaN       European Union 2023-02-01  182980797.0
# 242157  OWID_UMC            NaN  Upper middle income 2023-02-01  144137872.0
# 166387  OWID_NAM            NaN        North America 2023-02-01  121165892.0
# 240232       USA  North America        United States 2023-02-01  102451346.0
# 133617  OWID_LMC            NaN  Lower middle income 2023-02-01   97098752.0
# 212039  OWID_SAM            NaN        South America 2023-02-01   67620133.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %% [markdown]
# Buscando na documentação da base de dados e no dicionário de variáveis, vemos que na coluna `iso_code` as linhas que começam com o prefixo "OWID", são referentes a regiões maiores do que países, como por exemplo continentes, áreas de alta concentração de renda e etc.
#
# Como neste momento só queremos olhar para os países especificamente, irei remover as linhas que contém este prefixo.

# %%
#removendo linhas que contém o prefixo "OWID" na coluna iso_code
#criando nova coluna auxiliar para identificar o prefixo OWID
df['nao_pais'] = df['iso_code'].str.startswith('OWID')

#filtrando do dataframe somente as linhas que contem o valor Falso na coluna "nao_pais"
df_pais = df[df["nao_pais"] == False]

# %%
del df_pais['nao_pais']

# %% [markdown]
# Agora sim, podemos identificar quais os países com mais casos e mortes por COVID-19.
#
# Neste caso irei filtrar os TOP 5 países com o maior número de casos.

# %%
df_pais.loc[df.date == '2023-02-01'].sort_values(by='total_cases', ascending= False)[0:5]
# Out:
#        iso_code      continent       location       date  total_cases  \
# 240232      USA  North America  United States 2023-02-01  102451346.0
# 104574      IND           Asia          India 2023-02-01   44684248.0
# 80628       FRA         Europe         France 2023-02-01   39568875.0
# 85965       DEU         Europe        Germany 2023-02-01   37796790.0
# 32032       BRA  South America         Brazil 2023-02-01   36837943.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 240232   114592.0           38059.286     1109591.0      1261.0
# 104574      128.0              98.000      530741.0         1.0
# 80628      4506.0            4375.857      164355.0        53.0
# 85965     16957.0           11684.286      165865.0       154.0
# 32032     13363.0            9895.143      697200.0       126.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 240232              439.429  ...          24.6                     NaN
# ...

# %% [markdown]
# Podemos ver com base nas informações acima, que os cinco países com mais casos, são respectivamente:
#
# *   Estados Unidos: 102.451.346 casos
# *   Índia: 44.684.248 casos
# *   França: 39.568.875 casos
# *   Alemanha: 37.796.790 casos
# *   Brasil: 36.837.943 casos
#
#
#
# Agora os TOP 5 países com mais mortes:

# %%
df_pais.loc[df.date == '2023-02-01'].sort_values(by='total_deaths', ascending= False)[0:5]
# Out:
#        iso_code      continent       location       date  total_cases  \
# 240232      USA  North America  United States 2023-02-01  102451346.0
# 32032       BRA  South America         Brazil 2023-02-01   36837943.0
# 104574      IND           Asia          India 2023-02-01   44684248.0
# 188776      RUS         Europe         Russia 2023-02-01   21649414.0
# 146397      MEX  North America         Mexico 2023-02-01    7377333.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 240232   114592.0           38059.286     1109591.0      1261.0
# 32032     13363.0            9895.143      697200.0       126.0
# 104574      128.0              98.000      530741.0         1.0
# 188776     8462.0            6905.429      387153.0        40.0
# 146397     9081.0            4148.714      332324.0       126.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 240232              439.429  ...          24.6                     NaN
# ...

# %% [markdown]
# Os países com mais mortes são:
#
# *   Estados Unidos: 1.109.591 mortes
# *   Brasil: 697.200 mortes
# *   Índia: 530.741 mortes
# *   Russia: 387.153 mortes
# *   México: 332.324 mortes
#
#
# Veja que não são os mesmos países que encontramos com o maior número de casos. Um fator que contribuiu muito para isso foi o ínício rápido da vacinação,  principalmente em países desenvolvidos na Europa.

# %%
top5_total_deaths = df_pais.loc[df.date == '2023-02-01', ['location', 'total_deaths']].sort_values(by="total_deaths", ascending=False)[0:5]

fig, ax = plt.subplots(figsize=(15,10))

# configurar as cores que usarei no plot
AZUL = "#003F5c" 
CINZA = "#9E9E9E"
CINZA_TEXTO = "#515151"
CINZA_GRAFICO = "#7B8FA1"
VERMELHO = "#850000"

#configurando a fonte
plt.rcParams['font.family'] = 'Arial'

#convertendo coluna de total_deaths para inteiros
top5_total_deaths = top5_total_deaths.astype({'total_deaths' : 'int64'})

#removendo tick labels do eixo Y
ax.set_yticks([])

#removendo spines da direita e superior
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#anotações nos pontos de dados
for i, j in enumerate(top5_total_deaths.total_deaths):

  ax.annotate(
      j,
      xy= (i,j),
      xytext= (-20,8),
      textcoords='offset points',
      fontsize= 12,
      fontweight='semibold',
      color = AZUL,
      )
  
#mudar range do eixo y
ax.set_ylim(0, 1160000)


#title
ax.text(-0.65, 1230000, 'Top 5 países com mais mortes por COVID-19', fontsize=24, color=CINZA_TEXTO, fontweight='bold')
ax.text(-0.65, 1190000, 'Dados coletados no dia 01 de fevereiro de 2023', fontsize=15, color=CINZA)

ax.bar('location', 'total_deaths', data=top5_total_deaths, color= AZUL)

plt.tight_layout()

# %% [markdown]
# Agora vejamos como o volume dos casos de COVID-19 se disseminaram ao longo da pandemia no Mundo, até o dia desta análise:

# %%
#gráfico de linha para mortes no mundo

world_deaths = df.loc[df.location == "World", ["total_deaths", "date"]].reset_index(drop=True)

#convertendo float para inteiros
world_deaths = world_deaths.astype({'total_deaths': int})

fig, ax = plt.subplots(figsize=(12,8))

#plot das linhas
ax.plot('date', 'total_deaths',
        data=world_deaths,
        linewidth = 3.5,
        color = AZUL
        )

#removendo spines da direita e superior
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#formatando labels do eixo Y
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])

#inserir scatter point no último valor da série


# anotações no último ponto de scatter

ax.annotate(
  world_deaths['total_deaths'].iat[-1],
  xy=(world_deaths['date'].iat[-1], world_deaths['total_deaths'].iat[-1]),
  xytext=(5, 0),
  textcoords='offset points',
  color=AZUL,
  fontsize=14,
  fontweight='semibold'
  )

#adicionando título
ax.text(-0.075, 1.06, "Mortes Acumuladas Mundialmente por COVID-19", color = CINZA_TEXTO, fontsize = 24, fontweight = 'bold', transform=ax.transAxes)
ax.text(-0.075, 1.02, "Valores atualizados até 01 de fevereiro de 2023", color = CINZA_TEXTO, fontsize = 15, transform = ax.transAxes)


#formatando labels do eixo y
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])

plt.tight_layout()

# %% [markdown]
# Podemos ver através do gráfico acima, que mundialmente, desde o início da pandemia, acumulam-se quase 7 milhões de mortes. Porém este número pode ser ainda maior devido a diversos fatores, como: casos não registrados devido a falta de testes, principalmente no inicio da pandemia; Locais de difícil acesso e/ou baixa infraestrutura, em que mortes podem simplesmente não ter sido registradas, e etc.

# %% [markdown]
# ### Vacinação
#
# Durante a pandemia houve uma grande polarização tanto por parte do público geral, quanto de alguns partidos políticos no âmbito da vacinação.
# Tal fenômeno social pode ser visto em grande parte do mundo.
#
# <center><img alt="Colaboratory logo" width="45%" src="https://images.unsplash.com/photo-1608422050828-485141c98429?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=673&q=80"></center>
#
# Neste dataset temos consolidado na variável `total_vaccinations` o número total de vacinas administradas por localidade e mundialmente. Com isso conseguimos comparar os números de casos e mortes, versus a vacinação e analisar se houve correlação entre essas grandezas.

# %%
#Transforma os tick de valores altos (Bilhões, milhões e milhares) em abreviações B, M e K.
def format_tick(tick_val, pos):
    if tick_val >= 1000000000:
        val = round(tick_val/1000000000, 1)
        new_tick_format = '{:}B'.format(val)
    elif tick_val >= 1000000:
        val = round(tick_val/1000000, 1)
        new_tick_format = '{:}M'.format(val)
    elif tick_val >= 1000:
        val = round(tick_val/1000, 1)
        new_tick_format = '{:}K'.format(val)
    elif tick_val < 1000:
        new_tick_format = round(tick_val, 1)
    else:
        new_tick_format = tick_val

    # Transformar new_tick_format em string.
    new_tick_format = str(new_tick_format)
    
    # Remove o "0" após o ponto decimal.
    index_of_decimal = new_tick_format.find(".")
    
    if index_of_decimal != -1:
        value_after_decimal = new_tick_format[index_of_decimal+1]
        if value_after_decimal == "0":
          
            # Remove o 0 após o ponto.
            new_tick_format = new_tick_format[0:index_of_decimal] + new_tick_format[index_of_decimal+2:]
            
    return new_tick_format

# %%
#data frame com valores mundiais
df_world = df.loc[df.location == 'World']
fig, ax = plt.subplots(figsize=(16,12), nrows = 2, ncols = 1)

#plot número de casos
ax[0].stackplot('date', 'new_deaths',
        data=df_world,
        linewidth = 3.5,
        color = AZUL
        )
ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)

ax[0].text(0, 1.06, "Mortes Diárias Mundialmente por COVID-19", color = CINZA_TEXTO, fontsize = 15, fontweight = 'bold', transform=ax[0].transAxes)
ax[0].yaxis.set_major_formatter(tick.FuncFormatter(format_tick))


#plot número de pessoas vacinadas
ax[1].plot('date', 'people_vaccinated',
        data=df_world,
        linewidth = 3.5,
        color = VERMELHO
        )

ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)

ax[1].text(0, 1.06, "Total de pessoas vacinadas Mundialmente", color = CINZA_TEXTO, fontsize = 15, fontweight = 'bold', transform=ax[1].transAxes)
ax[1].yaxis.set_major_formatter(tick.FuncFormatter(format_tick))
plt.tight_layout()

# %% [markdown]
# Observe que conforme o aumento do número de pessoas vacinadas, houve um declínio no número de mortes diárias, o que mostra uma possível correlação entre as variáveis.
# É possível observar que o número de mortes por dia caiu significativamente a partir de maio de 2022, que também é o período logo após a curva mais acentuada de vacinação global.
#
# Observa-se também que há um outlier presente nos dados, onde para o dia 15 de janeiro de 2023 há um total de 60 mil mortes eu apenas um dia, o que é maior até mesmo do que durante o pico da pandemia. Para que este valor não atrapalhe nossa análise, a linha contendo este dado será removida do data frame.

# %%
df_copy = df.drop(df[df.new_deaths > 60000].index)
df_world = df_copy.loc[df_copy.location == 'World']

# %%
#data frame com valores mundiais
fig, ax = plt.subplots(figsize=(16,12), nrows = 2, ncols = 1)

#plot número de casos
ax[0].stackplot('date', 'new_deaths',
        data=df_world,
        linewidth = 3.5,
        color = AZUL
        )
ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)

ax[0].text(0, 1.06, "Mortes Diárias Mundialmente por COVID-19", color = CINZA_TEXTO, fontsize = 15, fontweight = 'bold', transform=ax[0].transAxes)
ax[0].yaxis.set_major_formatter(tick.FuncFormatter(format_tick))


#plot número de pessoas vacinadas
ax[1].plot('date', 'people_vaccinated',
        data=df_world,
        linewidth = 3.5,
        color = VERMELHO
        )

ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)

ax[1].text(0, 1.06, "Total de pessoas vacinadas Mundialmente", color = CINZA_TEXTO, fontsize = 15, fontweight = 'bold', transform=ax[1].transAxes)
ax[1].yaxis.set_major_formatter(tick.FuncFormatter(format_tick))
plt.tight_layout()

# %% [markdown]
# Um gráfico interessante que podemos plotar é o de dispersão, considerando o produto interno bruto per capita de cada país, versus o número de mortes:

# %%
df_pais['gdp_per_capita'].describe()
# Out:
# count    202493.000000
# mean      19570.590795
# std       20614.866310
# min         661.240000
# 25%        4227.630000
# 50%       12951.839000
# 75%       27936.896000
# max      116935.600000
# Name: gdp_per_capita, dtype: float64

# %%
fig2, ax2 = plt.subplots(figsize=(15,13))

df_pais[df_pais.date =='2023-02-01'].plot.scatter(x='gdp_per_capita', y='total_deaths', ax=ax2, c='Blue')
ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.set_title(
    "GDP per capita vs Número de Mortes - Escala Logarítmica",
    fontsize = 15,
    color = CINZA_TEXTO,
    fontweight = "bold"
    )

plt.tight_layout()

# %% [markdown]
# Podemos observar que mesmo países com um PIB maior, tiveram um grande número de mortos pela COVID-19. O que indica que somente o desenvolvimento econômico do pais não é um fator decisivo em tempos de pandemia. A situação política, cultural, a presença ou não de um sistema público de saúde, entre outros fatores, precisam ser avaliados com igual importância.

# %% [markdown]
# ### Análise Exploratória para o Brasil

# %% [markdown]
# Já que tivemos um panorama de comose comportou a pandemia em níveis globais, vamos olhar especificamente para o Brasil.
# Para isso vamos isolar os dados referentes ao Brasil em um dataframe específico.
#
# <center><img alt="Colaboratory logo" width="75%" src="https://img.freepik.com/free-photo/closeup-shot-black-pin-brazil-country-map_181624-7266.jpg?w=1380&t=st=1674924484~exp=1674925084~hmac=7ed0047ff2d4fe5690c4a52237f5c9ac7cb4b9b5ec212243979e40f21637324b"></center>

# %%
#criando dataframe para o Brasil
df_brasil = df.loc[df.location == "Brazil"].copy()

df_brasil.head()
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 30961      BRA  South America   Brazil 2020-02-26          1.0        1.0
# 30962      BRA  South America   Brazil 2020-02-27          1.0        0.0
# 30963      BRA  South America   Brazil 2020-02-28          1.0        0.0
# 30964      BRA  South America   Brazil 2020-02-29          2.0        1.0
# 30965      BRA  South America   Brazil 2020-03-01          2.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 30961                 NaN           NaN         0.0                  NaN  ...
# 30962                 NaN           NaN         0.0                  NaN  ...
# 30963                 NaN           NaN         0.0                  NaN  ...
# 30964                 NaN           NaN         0.0                  NaN  ...
# 30965                 NaN           NaN         0.0                  NaN  ...
#
# ...

# %% [markdown]
# Vamos verificar agora quando ocorreram o primeiro caso e a primeira morte no Brasil.

# %%
#qual foi a data do primeiro caso no Brasil?
primeiro_caso = df_brasil.loc[df_brasil.new_cases != 0.0, ['date', 'new_cases']].sort_values(by="date", ascending=True).head(1)
print("O primeiro caso identificado no Brasil ocorreu no dia: {} ".format(df_brasil.date.loc[primeiro_caso.index[0]]))
# Out:
# O primeiro caso identificado no Brasil ocorreu no dia: 2020-02-26 00:00:00

# %%
#qual foi a data da primeira morte no Brasil?
primeira_morte = df_brasil.loc[(df_brasil.new_deaths != 0.0) & (df_brasil.new_deaths.isnull() == False)].head(1)
print("A primeira morte identificada ocorreu no dia {}".format(df_brasil.date.loc[primeira_morte.index[0]]))
# Out:
# A primeira morte identificada ocorreu no dia 2020-03-17 00:00:00

# %% [markdown]
# Quanto tempo decorreu entre a primeira morte e o primeiro caso?

# %%
# Identificar quantos dias demorou para registrarmos a primeira morte, considerando o primeiro caso de COVID-19 registrado.
# calculando tempo desde o primeiro caso até a primeira morte

from datetime import date

delta = df_brasil.date.loc[primeira_morte.index[0]] - df_brasil.date.loc[primeiro_caso.index[0]]
print("Entre o primeiro caso e a primeira morte no Brasil se passaram {} dias.".format(delta.days))
# Out:
# Entre o primeiro caso e a primeira morte no Brasil se passaram 20 dias.

# %% [markdown]
# Vemos que o primeiro caso registrado no Brasil foi no dia 26 de fevereiro de 2020, logo um dia após o início do carnaval daquele ano. Não se sabe ao certo qual o impacto do carnaval de 2020 na progressão da pandemia, porém é razoável a hipótese de que este possa ter contrinbuído para a disseminação do vírus, visto o grande número de pessoas nas ruas.
#
# Abaixo segue o gráfico com a evolução dos casos de COVID no Brasil, desde o início da pandemia.

# %%
fig, ax = plt.subplots(figsize=(12,8))

#convertendo float para inteiros
df_brasil = df_brasil.astype({'total_cases': int})

#plot das linhas
ax.plot('date', 'total_cases',
        data=df_brasil,
        linewidth = 3.5,
        color = AZUL
        )

#removendo spines da direita e superior
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#formatando labels do eixo Y
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])

#inserir scatter point no último valor da série


# anotações no último ponto de scatter

ax.annotate(
  df_brasil['total_cases'].iat[-1],
  xy=(df_brasil['date'].iat[-1], df_brasil['total_cases'].iat[-1]),
  xytext=(5, 0),
  textcoords='offset points',
  color=AZUL,
  fontsize=14,
  fontweight='semibold'
  )

#adicionando título
ax.text(-0.075, 1.06, "Evolução do total de casos de COVID-19 no Brasil", color = CINZA_TEXTO, fontsize = 24, fontweight = 'bold', transform=ax.transAxes)
ax.text(-0.075, 1.02, "Valores atualizados até 01 de fevereiro de 2023", color = CINZA_TEXTO, fontsize = 15, transform = ax.transAxes)


#formatando labels do eixo y
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])

plt.tight_layout()

# %% [markdown]
# Para finalizar a análise dos dados, irei plotar os gráficos de casos totais e mortes no Brasil, em escala linear e logarítmica.

# %%
# Plotar gráficos de linha em escalas linear e logarítmica para os casos totais e mortes totais.

x = df_brasil['date']
y = df_brasil['total_cases']
y2 = df_brasil['total_deaths']

fig, ((ax1,ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(25,12))

#casos totais em escala linear
ax1.set_title("Casos no Brasil")

ax1.set_ylabel("Número de Casos")
ax1.plot(x,y)
ax1.yaxis.set_major_formatter(tick.FuncFormatter(format_tick))
#casos totais em escala logarítmica
ax2.set_title("Casos no Brasil - Escala Logarítmica")

ax2.set_ylabel("Número de Casos")
ax2.set_yscale('log')
ax2.plot(x,y)
ax2.yaxis.set_major_formatter(tick.FuncFormatter(format_tick))

#mortes totais em escala linear
ax3.set_title("Mortes no Brasil")

ax3.set_ylabel("Número de Mortes")
ax3.plot(x,y2)
ax3.yaxis.set_major_formatter(tick.FuncFormatter(format_tick))

#mortes totais em escala logarítmica
ax4.set_title("Mortes no Brasil - Escala Logarítmica")

ax4.set_ylabel("Número de Mortes")
ax4.set_yscale('log')
ax4.plot(x,y2)
ax4.yaxis.set_major_formatter(tick.FuncFormatter(format_tick))


plt.tight_layout()

# %% [markdown]
# ## Conclusão
#
# Com base nos dados apresentados neste artigo, podemos verificar que os Estados Unidos lideram em número de casos e mortes. Lá, a vacinação teve início tardio, e houve um movimento muito grande contra a as vacinas por parte da população. Isso corrobora para o fato de existirem tantas mortes neste país.
#
# Observamos também que os países com mais casos não são necessáriamente os países com mais mortes. O que é um indicador para a importância das vacinas e tratamentos durante a pandemia. Óbvio que, outros fatores precisam também ser analisados, como idade média da população, predominância de fatores de risco e etc.
#
# Analisando os dados de vacinação e relacionando-os com o número de mortes globalmente, podemos estabelecer uma correlação entre as duas variáveis, tendo em vista que aproxidamente em maio de 2022 houve a consolidação de um maior número de pessoas e neste mesmo período as mortes diárias reduziram drasticamente. Somando isto as recomendações da OMS e do ministério da saúde no Brasil, fica evidente que as vacinas tiveram papel fundamental no controle da pandemia de COVID-19.
#
# No Brasil assim como na maioria dos Países, o número de mortes também está regredindo em ritmo constante, rumo a uma estabilização.
#
# Porém é importante ressaltar que novos casos e novas mortes ainda acontecem, mesmo com todas as medidas atuais de prevenção. Portanto é recomendável manter-se os hábitos adquiridos na pandemia, como higienização das mãos, o uso de máscara por pessoas doentes ou com suspeita de COVID-19 e a vacinação da população.
#
# Por fim, podemos concluir que a pandemia deixou cicatrizes na sociedade em diversos âmbitos, principalmente no grande número de infectados e de fatalidades. Fica a sugestão para próximos trabalhos de comparar esta base de dados com outras disponíveis a fim de validar outras hipóteses e comparar outras variáveis.
